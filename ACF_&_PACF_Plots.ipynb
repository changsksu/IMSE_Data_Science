# %% [markdown]
# <a href="https://colab.research.google.com/github/changsksu/IMSE_Data_Science/blob/main/ACF_%26_PACF_Plots.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # This demo shows how to diagnose a time series so that proper ARMA model can be used. Both AR(1) and MA(1) data sets are demonstracted. Both csv files are on Github.

# %%
import math
import statistics
import numpy as np
import scipy.stats
import pandas as pd
import matplotlib.pyplot as plt

# %%
#the 2nd read option assume that the data file is rignt under your default google drive directory
# the sep-',' argument in the read statement should be used in some cases if ; does not work
data = pd.read_csv('https://raw.githubusercontent.com/changsksu/K-State-IMSE641/master/AR1.csv', sep=',', na_values=".")
data.head()
# Out:
#           xt
# 0  10.321142
# 1   9.155861
# 2   7.447477
# 3   6.770342
# 4   6.149980

# %%
# is this time series stationary?
plt.plot(data)

# %%
from statsmodels.graphics.tsaplots import plot_acf
plot_acf(data, lags=20)

# %%
from statsmodels.graphics.tsaplots import plot_pacf
plot_pacf(data, lags=20)
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# From both acf and pacf plots above, acf shows a sin wave and pacf shows one spike. The most likely ARIMA model is AR(1).

# %% [markdown]
# # Now let's examine the ACF and PACF charts for MA1 data

# %%
data2 = pd.read_csv('https://raw.githubusercontent.com/changsksu/K-State-IMSE641/master/MA1.csv', sep=',', na_values=".")
data2.head()
# Out:
#           xt
# 0  10.211996
# 1  10.692098
# 2   8.645758
# 3  11.744829
# 4   9.010084

# %%
plot_acf(data2, lags=20)

# %%
plot_pacf(data2, lags=20)
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/regression/linear_model.py:1358: RuntimeWarning: invalid value encountered in sqrt
#   return rho, np.sqrt(sigmasq)

# %% [markdown]
# The above ACF and PACF plots show that there is one spike in ACF and most PACF lines are in check. Most likely a AR(1) model will fit this time series well.

# %% [markdown]
# # if the time series data is independent, there should not be any spikes beyond the shadded area after lag 0.

# %%
# ACF plot for an independently distribution time series
sample_size = 100
data3 = np.random.normal(size=sample_size)
plt.plot(data3)
plot_acf(data3, lags=20)
plot_pacf(data3, lags=20)

# %% [markdown]
# The above ACF plot show that all spikes are small after lag 0 (the largest pike at lag0). Therefore, the data is independent.
