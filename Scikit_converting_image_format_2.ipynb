# %% [markdown]
# <a href="https://colab.research.google.com/github/changsksu/IMSE_Data_Science/blob/main/Scikit_converting_image_format_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Scikit Example of color to gray and color to HSV
#
# ---
# HSV is (Hue, Saturation, Value) ref.  https://www.geeksforgeeks.org/image-segmentation-using-pythons-scikit-image-module/

# %%
# Importing Necessary Libraries
import numpy as np
from skimage import data
from skimage.color import rgb2gray
import matplotlib.pyplot as plt

# %%
# Setting the plot size to 15,15
plt.figure(figsize=(15, 15))
 
# Sample Image of scikit-image package
coffee = data.coffee()
plt.subplot(1, 2, 1)
 
# Displaying the sample image
plt.imshow(coffee)
# Converting RGB image to Monochrome
gray_coffee = rgb2gray(coffee)
plt.subplot(1, 2, 2)
 
# Displaying the sample image - Monochrome
# Format
plt.imshow(gray_coffee, cmap="gray")

# %% [markdown]
# Explanation: By using rgb2gray() function, the 3-channel RGB image of shape (400, 600, 3) is converted to a single-channel monochromatic image of shape (400, 300).

# %%
plt.imshow(gray_coffee,cmap="gray")

# %% [markdown]
# # Your Turn: convert the above grayscale image so that the image looks like a negative, i.e. white becomes black and black becomes write

# %%
gray_coffee.shape
# Out:
# (400, 600)

# %%
for value in gray_coffee:
  print(value)

# %%
nr=int(len(gray_coffee.mean(axis=1)))
nc=int(len(gray_coffee.mean(axis=0)))
print("number of rows=", nr)
print("number of columns=", nc)
# Out:
# number of rows= 400
# number of columns= 600

# %%
negative_coffee=np.zeros_like(gray_coffee)
negative_coffee.shape
plt.imshow(negative_coffee, cmap="gray")

# %%
negative_coffee=np.zeros_like(gray_coffee)
for i in range(0, nr):
    for j in range(0, nc):
        negative_coffee[i][j]=1-gray_coffee[i][j]
    
# plt.imshow(negative_coffee, cmap="gray")

# Displaying the sample image
# Setting the plot size to 15,15
plt.figure(figsize=(15, 15))
plt.imshow(gray_coffee,cmap="gray")
plt.subplot(1, 2, 1)
plt.imshow(negative_coffee, cmap="gray")
plt.subplot(1, 2, 2)

# %%
new_image = []
for i in range(0, nr):
    for j in range(0, nc):
        new_image.append( 255.0 - j)
    
#plt.imshow(gray_coffee, cmap="gray")

# %%
np.shape(new_image)
# Out:
# (240000,)

# %%
np.reshape?

# %%
new= np.reshape(new_image,(400,600))
plt.imshow(new.astype(float))

# %%
for i in range(0, nr):
    for j in range(0, 300):
      print(j)

# %% [markdown]
# Debugging: what is wrong with the code above?

# %% [markdown]
# # The HSV (Hue, Saturation, Value) color model remaps the RGB basic colors into dimensions that are simpler to comprehend for humans.

# %%
# Importing Necessary Libraries
from skimage import data
from skimage.color import rgb2hsv
import matplotlib.pyplot as plt
 
# Setting the plot size to 15,15
plt.figure(figsize=(15, 15))
 
# Sample Image of scikit-image package
coffee = data.coffee()
plt.subplot(1, 2, 1)
 
# Displaying the sample image
plt.imshow(coffee)
 
# Converting RGB Image to HSV Image
hsv_coffee = rgb2hsv(coffee)
plt.subplot(1, 2, 2)
 
# Displaying the sample image - HSV Format
hsv_coffee_colorbar = plt.imshow(hsv_coffee)
 
# Adjusting colorbar to fit the size of the image
plt.colorbar(hsv_coffee_colorbar, fraction=0.046, pad=0.04)
